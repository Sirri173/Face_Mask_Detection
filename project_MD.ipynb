# %%
import numpy as np
import cv2

# %%
with_mk = np.load('with_mk.npy')
without_mk = np.load('without_mk.npy')

# %%
with_mk.shape
# Out:
# (200, 50, 50, 3)

# %%
without_mk.shape
# Out:
# (200, 50, 50, 3)

# %%
with_mk = with_mk.reshape(200,50 * 50 * 3)
without_mk = without_mk.reshape(200, 50 * 50 * 3)

# %%
with_mk.shape
# Out:
# (200, 7500)

# %%
without_mk.shape
# Out:
# (200, 7500)

# %%
X = np.r_[with_mk, without_mk]

# %%
X.shape
# Out:
# (400, 7500)

# %%
labels = np.zeros(X.shape[0])

# %%
labels[200:] = 1.0

# %%
names = {0 : 'Mask', 1 : 'No Mask'}

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X, labels, test_size=0.25)

# %%
x_train.shape
# Out:
# (300, 7500)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=3)
x_train = pca.fit_transform(x_train)

# %%
x_train[0]
# Out:
# array([2175.69959463,  671.23190466, 4118.01429359])

# %%
x_train.shape
# Out:
# (300, 3)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, labels, test_size=0.20)

# %%
svm = SVC()
svm.fit(x_train, y_train)
# Out:
# SVC()

# %%
# x_test = pca.transform(x_test)
y_pred = svm.predict(x_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
capture = cv2.VideoCapture(0)
data = []
font = cv2.FONT_HERSHEY_COMPLEX
while True:
    flag, img = capture.read()
    if flag:
        fc = faceCascade.detectMultiScale(img)
        for x,y,w,h in fc:
            cv2.rectangle(img, (x,y), (x+w, y+h), (255,0,255), 4)
            fc = img[y:y+h, x:x+w, :]
            fc = cv2.resize(fc, (50,50))
            fc = fc.reshape(1,-1)
            #fc = pca.transform(fc)
            pred = svm.predict(fc)
            n = names[int(pred)]
            cv2.putText(img, n, (x,y), font, 1, (244,250,250), 2)
            print(n)
        cv2.imshow('result',img)
        if cv2.waitKey(2) == 27:
            break
            
capture.release()
cv2.destroyAllWindows()
# Out:
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# No Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# No Mask
# No Mask
# Mask
# No Mask
# No Mask
# Mask
# Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# Mask
# No Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# ...
